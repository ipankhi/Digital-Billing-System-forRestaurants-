# %%
def menu():
    print ("Menu")
    print("Sl no.\t\t\t\t\tItems\t\t\t\tPrice\n1\t\t\t\tchai\t\t\t\t10\n2\t\t\t\tcoffee\t\t\t\t20\n3\t\t\t\tsamosa\t\t\t\t15\n4\t\t\t\tnoodles\t\t\t\t40\n5\t\t\t\tparatha\t\t\t\t30")
    choosed_item=int(input("What would you like to have?Select the item no.If nothing press 0."))
    if choosed_item!=0:
        x=[]
        y=[]
        x.append(choosed_item)
        y.append(int(input("enter the quantity")))
        bill(x,y)
    if choosed_item==0:
        print("Thank you")
    


def price():
        10
        30
        15
        45
        40

def items_to_no():
        if 'chai':
             return 1
        elif 'coffee':
             return 2
        elif 'samosa':
             return 3
        elif 'chicken noodles':
             return 4
        elif 'veg noodles':
             return 5
def no_to_price():
        if 1:
            return 10
        elif 2:
            return 30
        elif 3:
            return 15
        elif 4:
            return 45
        elif 5:
            return 40
def bill(x,y):
    total=[]
    sum=0
    for i in range(len(x)):
        if x[i]==1:
            total.append(10)
        elif x[i]==2:
            total.append(30)
        elif x[i]==3:
             total.append(15)
        elif x[i]==4:
            total.append(45)
        elif  x[i]==5:
             total.append(40)
        sum=sum+total[i]*y[i]       
        print("Your total amount is:",sum)
        final=int(input("To confirm order place 1 or to exit press 0"))
        if final==0:
            print("Thank you")
        else:
            print("your order will be served in a few minutes")
print("WELCOME TO FOOD PLAZZA")
choice=int(input("Press 1 to check the menu or press 0 to exit"))
if choice==1:
    
    menu()
# Out:
# WELCOME TO FOOD PLAZZA
# Press 1 to check the menu or press 0 to exit1
# Menu
# Sl no.					Items				Price
# 1				chai				10
# 2				coffee				20
# 3				samosa				15
# 4				noodles				40
# 5				paratha				30
# What would you like to have?Select the item no.If nothing press 0.3
# enter the quantity3
# Your total amount is: 45
# To confirm order place 1 or to exit press 00
# Thank you
